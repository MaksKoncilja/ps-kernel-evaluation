# %%
import importlib
import numpy as np
import pandas as pd

import reference
importlib.reload(reference)
# Out:
# -14.423189983098714 192 1023.9015242591784 0.5765814903098375 117.41659562502173

# %%
out_mala = reference.run_reference_sampler_once(
    dimension=5,
    num_particles=1024,
    seed=0,
    target_name="gaussian_mixture",
    num_mcmc_steps=10,
    kernel_name="mala",
    mala_step_size=0.02,
    return_diagnostics=False,
)

print(out_mala["logZ"], out_mala["n_iter"], out_mala["final_ess"], out_mala["acceptance_rate_mean"], out_mala["runtime_sec"])
# Out:
# -14.423189983098714 192 1023.9015242591784 0.5765814903098375 115.24410787501256
